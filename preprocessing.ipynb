# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('shapeOfYouComments.csv')
df.tail()
# Out:
#                  Author                                            Comment  \
# 16328                Ak                     Ending is really awesome 🤣🤣🤣🤣🤣
# 16329  Ramida Seedapeng                                   I like this song
# 16330       manju sarma                                        Really gold
# 16331      Youngmac1661  I know u probably not reading this but I  love...
# 16332             T-man              These rhymes are on a different level
#
#                Publish_Date Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 16328  2022-01-17T03:44:40Z        NaN        NaN        NaN        NaN
# 16329  2022-01-17T03:32:39Z        NaN        NaN        NaN        NaN
# 16330  2022-01-17T03:27:19Z        NaN        NaN        NaN        NaN
# 16331  2022-01-17T03:00:21Z        NaN        NaN        NaN        NaN
# 16332  2022-01-17T02:33:33Z        NaN        NaN        NaN        NaN
#
#       Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 20 Unnamed: 21  \
# ...

# %%
df3 = df[['Author','Comment']].copy()
df3.head(25)
# Out:
#                               Author  \
# 0                        Don Gillies
# 1                           Dogeball
# 2                   Varifiable Jelly
# 3                               たきくん
# 4                      Nirmala Gowda
# 5                             PRO FF
# 6                     Karna Debbarma
# 7                              cyh_7
# 8     08_Farhat Ferdiansyah_X MIPA 4
# 9                         Angel Khoo
# 10                      los crak (V)
# 11                      _.teef5211._
# 12                         10toesdwn
# 13                    Havila Assande
# 14                   DarkMoonGeneral
# 15                   si yuan wanglow
# 16                     عبوسي البياتي
# 17   1 BILHÃO DE INSCRITOS SEM VIDEO
# 18                  Jennifer Stetson
# 19  Henry sebastian Dominguez aquino
# 20                       GN LEARNING
# 21           Viviguilherme Guilherme
# 22                      Chai y Elías
# 23                            SufZee
# ...

# %%
df3['Comment']
# Out:
# 0        Nothing better than being young and in love.  ...
# 1                                           this song. . .
# 2                       5 years and it ain’t stopped. Dang
# 3        there is literally nobody in this world who do...
# 4                                                 Me I&#39
#                                ...
# 16328                       Ending is really awesome 🤣🤣🤣🤣🤣
# 16329                                     I like this song
# 16330                                          Really gold
# 16331    I know u probably not reading this but I  love...
# 16332                These rhymes are on a different level
# Name: Comment, Length: 16333, dtype: object

# %%
df3['Comment'] = df3['Comment'].str.replace(r'<[^<>]*>', '', regex=True)  #remove html tags

# %%
df3.tail(10)
# Out:
#                  Author                                            Comment
# 16323  Kadhiravan Oviya                                                OMG
# 16324       ᴊ.ᴠ.ᴀʙɪsʜᴇᴋ                      Travel+ shape of you=heaven 😘
# 16325            DANGER                ED SHEERAN INTERNATIONAL BEST AWARD
# 16326            DANGER                                         Ed Sheeran
# 16327        bugha mans                                            w music
# 16328                Ak                     Ending is really awesome 🤣🤣🤣🤣🤣
# 16329  Ramida Seedapeng                                   I like this song
# 16330       manju sarma                                        Really gold
# 16331      Youngmac1661  I know u probably not reading this but I  love...
# 16332             T-man              These rhymes are on a different level

# %%
# !pip install demoji
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import demoji
text =" "
emojiDic ={}
for i in range(len(df3['Comment'])):
    text = text + str(df3['Comment'][i])
emojiDic = demoji.findall(text)

# %%
print(emojiDic)
# Out:
# {'🙏🏻': 'folded hands: light skin tone', '🤫': 'shushing face', '📃': 'page with curl', '☠': 'skull and crossbones', '🔨': 'hammer', '🥸': 'disguised face', '🦮': 'guide dog', '🖍️': 'crayon', '🐙': 'octopus', '🛡️': 'shield', '🌓': 'first quarter moon', '🍨': 'ice cream', '🇸🇱': 'flag: Sierra Leone', '🇯🇵': 'flag: Japan', '📀': 'dvd', '🎷': 'saxophone', '🇾🇹': 'flag: Mayotte', '💐': 'bouquet', '🪚': 'carpentry saw', '💃': 'woman dancing', '😺': 'grinning cat', '👍🏼': 'thumbs up: medium-light skin tone', '🌟': 'glowing star', '🐒': 'monkey', '🐦': 'bird', '🌻': 'sunflower', '🎨': 'artist palette', '🖕': 'middle finger', '⚡': 'high voltage', '👉': 'backhand index pointing right', '💃🏽': 'woman dancing: medium skin tone', '❤\u200d🩹': 'mending heart', '🍡': 'dango', '🌴': 'palm tree', '🕺🏻': 'man dancing: light skin tone', '👙': 'bikini', '🕋': 'kaaba', '🫂': 'people hugging', '🦶🏽': 'foot: medium skin tone', '🧗': 'person climbing', '😵\u200d💫': 'face with spiral eyes', '🦴': 'bone', '🥶': 'cold face', '💁': 'person tipping h
# ...

# %%
df3.replace(emojiDic,inplace=True,regex=True)

# %%
df3.tail(10) #succesfully converted all emojis to text
# Out:
#                  Author                                            Comment
# 16323  Kadhiravan Oviya                                                OMG
# 16324       ᴊ.ᴠ.ᴀʙɪsʜᴇᴋ    Travel+ shape of you=heaven face blowing a kiss
# 16325            DANGER                ED SHEERAN INTERNATIONAL BEST AWARD
# 16326            DANGER                                         Ed Sheeran
# 16327        bugha mans                                            w music
# 16328                Ak  Ending is really awesome rolling on the floor ...
# 16329  Ramida Seedapeng                                   I like this song
# 16330       manju sarma                                        Really gold
# 16331      Youngmac1661  I know u probably not reading this but I  love...
# 16332             T-man              These rhymes are on a different level
